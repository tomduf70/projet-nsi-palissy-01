# %% [markdown]
# <a href="https://colab.research.google.com/github/tomduf70/projet-nsi-palissy-01/blob/master/Astuces_pour_images_dans_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Import du module PIL
from PIL import Image
import requests

# %%
#

maPremiereImage = Image.open(requests.get("https://picsum.photos/400/400", stream=True).raw)
display(maPremiereImage)

# Accès à une image sur Drive
# Accès à Drive
'''from google.colab import drive
drive.mount('/content/drive')

#Listing des fichiers du dossier
# !ls "/content/drive/Shared drives/_NSI/Bac à sable/tomduf/Script expérimentaux"

# ouverture du fichier bmp
chemin = "/content/drive/Shared drives/_NSI/Bac à sable/tomduf/Script expérimentaux"
maSecondeImage = Image.open(chemin + "/165-640x480.bmp")
display(maSecondeImage)
'''
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F03B5220B70>
# 'from google.colab import drive\ndrive.mount(\'/content/drive\')\n\n#Listing des fichiers du dossier\n!ls "/content/drive/Shared drives/_NSI/Bac à sable/tomduf/Script expérimentaux"\n\n# ouverture du fichier bmp\nchemin = "/content/drive/Shared drives/_NSI/Bac à sable/tomduf/Script expérimentaux"\nmaSecondeImage = Image.open(chemin + "/165-640x480.bmp")\ndisplay(maSecondeImage)\n'

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-6c94efe6-40bc-4fa6-92e3-a329f92bcde7" name="files[]" multiple disabled />
#      <output id="result-6c94efe6-40bc-4fa6-92e3-a329f92bcde7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Desert.jpg to Desert (1).jpg
# Saving Hydrangeas.jpg to Hydrangeas.jpg
# Saving Jellyfish.jpg to Jellyfish.jpg
# Saving Tulips.jpg to Tulips (1).jpg
# User uploaded file "Desert.jpg" with length 845941 bytes
# User uploaded file "Hydrangeas.jpg" with length 595284 bytes
# User uploaded file "Jellyfish.jpg" with length 775702 bytes
# User uploaded file "Tulips.jpg" with length 620888 bytes

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
